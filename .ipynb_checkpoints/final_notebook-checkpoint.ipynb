# %% [markdown]
# # Final project

# %% [markdown]
# #### import features

# %%
#matrix feature
import numpy as np
import pandas as pd

#visualisation
import matplotlib.pyplot as plt

# %% [markdown]
# ### import data

# %%
df = pd.read_excel("data/dif_alle.xls", header=None)

# %% [markdown]
# ### visualize data

# %%
# Create a line plot
plt.plot(df)

# Set plot title and labels
plt.title('Visualization of measurements')
plt.xlabel('LED')
plt.ylabel('Value')

# Show the plot
plt.show()
